# %% [markdown]
# # **Libraries**

# %% [markdown]
# Use this line if you don't have downloaded the python libraries

# %%
# !pip install pandas==2.0.3
# !pip install numpy==1.25.2
# !pip install requests==2.29.0

# %% [markdown]
# Run libraries

# %%
import os
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# # **Read Data**

# %% [markdown]
# Read data and create the file

# %%
## download the dataset
# Directory of the raw data files
_data_root = '../Diabetes'
# Path to the raw training data
_data_filepath = os.path.join(_data_root, 'Diabetes.csv')
# Download data
os.makedirs(_data_root, exist_ok=True)
if not os.path.isfile(_data_filepath):
    #https://archive.ics.uci.edu/ml/machine-learning-databases/covtype/
    url = 'https://docs.google.com/uc?export= \
    download&confirm={{VALUE}}&id=1k5-1caezQ3zWJbKaiMULTGq-3sz6uThC'
    r = requests.get(url, allow_redirects=True, stream=True)
    open(_data_filepath, 'wb').write(r.content)

# %% [markdown]
# # **Split Data**

# %%
df = pd.read_csv("../Diabetes/Diabetes.csv")
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?  \
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id
# 0                  6                        25                    1  \
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin
# ...

# %%
# X = df.drop(columns=["readmitted"])
# y = df["readmitted"] # .map({"ham": 0, "spam": 1})

# %% [markdown]
# Here we split the data set

# %%
train_split = 0.8973
val_split = 0.05135
df_provicional = df.sample(frac=1, random_state=42)
df_train, df_validation, df_test = np.split(df_provicional, [int(train_split * len(df_provicional)), int((train_split+val_split) * len(df_provicional))])

# %% [markdown]
# # **Review and save dataframes in csv**

# %%
print(len(df_train))
df_train.to_csv("../Diabetes/diabetes_train.csv")
df_train.head()
# Out:
# 91314
#        encounter_id  patient_nbr             race  gender      age weight
# 35956     110939484     19274094        Caucasian  Female  [70-80)      ?  \
# 60927     170328306     65634327        Caucasian    Male  [50-60)      ?
# 79920     245688426    100657359        Caucasian  Female  [60-70)      ?
# 50078     150826224     83144448        Caucasian    Male  [30-40)      ?
# 44080     135993852     65234214  AfricanAmerican  Female  [60-70)      ?
#
#        admission_type_id  discharge_disposition_id  admission_source_id
# 35956                  1                         1                    6  \
# 60927                  1                         1                    1
# 79920                  3                         6                    1
# 50078                  2                         1                    1
# 44080                  1                         2                    7
#
#        time_in_hospital  ... citoglipton insulin  glyburide-metformin
# ...

# %%
print(len(df_validation))
df_validation.to_csv("../Diabetes/diabetes_val.csv")
df_validation.head()
# Out:
# 5226
#        encounter_id  patient_nbr       race  gender      age weight
# 88731     285778410     91465884  Caucasian  Female  [80-90)      ?  \
# 86310     274490130     40888386  Caucasian  Female  [50-60)      ?
# 86268     274327332     97411455  Caucasian  Female  [50-60)      ?
# 69103     195906000     94605066  Caucasian  Female  [80-90)      ?
# 7689       35968662     11605473  Caucasian    Male  [70-80)      ?
#
#        admission_type_id  discharge_disposition_id  admission_source_id
# 88731                  1                         3                    7  \
# 86310                  1                         1                    7
# 86268                  1                         1                    7
# 69103                  2                         3                    1
# 7689                   3                         1                    1
#
#        time_in_hospital  ... citoglipton insulin  glyburide-metformin
# ...

# %%
print(len(df_test))
df_test.to_csv("../Diabetes/diabetes_test.csv")
df_test.head()
# Out:
# 5226
#        encounter_id  patient_nbr             race  gender      age weight
# 30257      97937160     16008777        Caucasian  Female  [20-30)      ?  \
# 35595     110139216     23507226        Caucasian  Female  [40-50)      ?
# 22164      76669422     90388089        Caucasian  Female  [70-80)      ?
# 70532     202592544     57904938        Caucasian    Male  [70-80)      ?
# 68798     194634186     20220642  AfricanAmerican  Female  [80-90)      ?
#
#        admission_type_id  discharge_disposition_id  admission_source_id
# 30257                  2                         1                    1  \
# 35595                  5                         1                   17
# 22164                  6                         1                   17
# 70532                  1                         7                    7
# 68798                  1                         1                    7
#
#        time_in_hospital  ... citoglipton insulin  glyburide-metformin
# ...
